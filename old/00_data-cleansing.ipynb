# %%
from IPython.core.interactiveshell import InteractiveShell
from IPython.display import display
InteractiveShell.ast_node_interactivity = "all"

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
# %matplotlib inline
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
SHEET_NAME_STOCK_INFO = "stock_info"
SHEET_NAME_STOCK_STATS = "stock_stats"
SHEET_NAME_STOCK_FINANCIALS = "stock_financials"
SHEET_NAME_STOCK_DIVIDENDS = "stock_dividends"

# %% [markdown]
# # Data Cleansing

# %%
stock_info = pd.read_excel("data/stock_info.xlsx", sheet_name=SHEET_NAME_STOCK_INFO, engine="openpyxl")
stock_stats = pd.read_excel("data/stock_stats.xlsx", sheet_name=SHEET_NAME_STOCK_STATS, engine="openpyxl")

# %%
len(stock_info), len(stock_info["symbol"].unique())
# Out:
# (8431, 8354)

# %%
len(stock_info[stock_info["symbol"].isna()])
# Out:
# 78

# %%
df = stock_info.dropna(subset=["symbol"])
len(df)
# Out:
# 8353

# %%
print(df.head(3))
# Out:
#    52WeekChange  SandP52WeekChange                      address1  algorithm  \
# 0     -0.241917          -0.111159  5301 Stevens Creek Boulevard        NaN
# 1     -0.123813          -0.111159           201 Isabella Street        NaN
# 2     -0.544291          -0.111159    3753 Howard Hughes Parkway        NaN
#
#    annualHoldingsTurnover  annualReportExpenseRatio     ask  askSize  \
# 0                     NaN                       NaN  129.88   1000.0
# 1                     NaN                       NaN   42.65   1200.0
# 2                     NaN                       NaN    0.00      0.0
#
#    averageDailyVolume10Day  averageVolume  averageVolume10days      beta  \
# 0                1702650.0      1502291.0            1702650.0  1.067119
# 1                7148020.0      5903343.0            7148020.0  2.318817
# 2               14718166.0     11042072.0           14718166.0  3.685976
#
#    beta3Year    bid  bidSize  bookValue  category  circulatingSupply  \
# 0        NaN  129.6    800.0     17.188       NaN                NaN
# 1        NaN   42.5    900.0     31.491       NaN                NaN
# 2        NaN    0.0      0.0      0.001       NaN                NaN
#
#           city  coinMarketCapLink companyOfficers        country currency  \
# 0  Santa Clara                NaN              []  United States      USD
# 1   Pittsburgh                NaN              []  United States      USD
# 2    Las Vegas                NaN              []  United States      USD
#
#    currentPrice  currentRatio  dateShortInterest   dayHigh  dayLow  \
# 0       129.890         1.940       1.661904e+09  132.1300  128.29
# 1        42.460         1.812       1.661904e+09   43.7600   41.61
# 2         0.052         3.515                NaN    0.0544    0.05
#
#    debtToEquity  dividendRate  dividendYield  earningsGrowth  \
# 0        60.361          0.84         0.0065           0.279
# 1        24.863          0.40         0.0094           0.810
# 2      1040.232           NaN            NaN             NaN
#
#    earningsQuarterlyGrowth        ebitda  ebitdaMargins  enterpriseToEbitda  \
# 0                    0.246  1.922000e+09        0.28863              21.045
# 1                    0.777  3.546000e+09        0.26490               2.662
# 2                      NaN -3.053686e+06        0.00000              -0.605
#
#    enterpriseToRevenue  enterpriseValue  exDividendDate exchange  \
# 0                6.074     4.044871e+10    1.656634e+09      NYQ
# 1                0.705     9.440624e+09    1.659917e+09      NYQ
# 2               36.572     1.846982e+06             NaN      PNK
#
#   exchangeTimezoneName exchangeTimezoneShortName  expireDate           fax  \
# 0     America/New_York                       EDT         NaN  866 497 1134
# 1     America/New_York                       EDT         NaN           NaN
# 2     America/New_York                       EDT         NaN           NaN
#
#    fiftyDayAverage  fiftyTwoWeekHigh  fiftyTwoWeekLow financialCurrency  \
# 0        129.80980        174.350000       112.520000               USD
# 1         48.77180         98.090000        39.565000               USD
# 2          0.06008          0.330297         0.045049               USD
#
#    fiveYearAverageReturn  fiveYearAvgDividendYield  floatShares  forwardEps  \
# 0                    NaN                      0.73  295090280.0        5.50
# 1                    NaN                       NaN  179000365.0        7.12
# 2                    NaN                       NaN          NaN         NaN
#
#    forwardPE  freeCashflow  fromCurrency  fullTimeEmployees  fundFamily  \
# 0  23.616364   829000000.0           NaN            17700.0         NaN
# 1   5.963483   898875008.0           NaN            12200.0         NaN
# 2        NaN    -1181078.0           NaN               42.0         NaN
#
#    fundInceptionDate  gmtOffSetMilliseconds  grossMargins  grossProfits  \
# 0                NaN            -14400000.0       0.54212  3.407000e+09
# 1                NaN            -14400000.0       0.28298  3.053000e+09
# 2                NaN            -14400000.0       1.00000  5.050300e+04
#
#    heldPercentInsiders  heldPercentInstitutions  impliedSharesOutstanding  \
# 0              0.00239                  0.93772                       0.0
# 1              0.00880                  0.86370                       0.0
# 2              0.00000                  0.00004                       NaN
#
#                            industry  isEsgPopulated  lastCapGain  \
# 0            Diagnostics & Research             NaN          NaN
# 1                          Aluminum             NaN          NaN
# 2  Other Industrial Metals & Mining             NaN          NaN
#
#    lastDividendDate  lastDividendValue  lastFiscalYearEnd  lastMarket  \
# 0      1.656634e+09               0.21       1.635638e+09         NaN
# 1      1.659917e+09               0.10       1.640909e+09         NaN
# 2               NaN                NaN       1.104451e+09         NaN
#
#    lastSplitDate lastSplitFactor  legalType  \
# 0   1.414973e+09       1398:1000        NaN
# 1   1.477958e+09        1000:801        NaN
# 2   1.663114e+09         101:100        NaN
#
#                                          logo_url  \
# 0           https://logo.clearbit.com/agilent.com
# 1             https://logo.clearbit.com/alcoa.com
# 2  https://logo.clearbit.com/asiabroadbandinc.com
#
#                                  longBusinessSummary  \
# 0  Agilent Technologies, Inc. provides applicatio...
# 1  Alcoa Corporation, together with its subsidiar...
# 2  Asia Broadband, Inc., through its subsidiary, ...
#
#                      longName     market     marketCap  maxAge  maxSupply  \
# 0  Agilent Technologies, Inc.  us_market  3.845276e+10     1.0        NaN
# 1           Alcoa Corporation  us_market  7.639615e+09     1.0        NaN
# 2        Asia Broadband, Inc.  us_market  2.140564e+07     1.0        NaN
#
#     messageBoardId  morningStarOverallRating  morningStarRiskRating  \
# 0     finmb_154924                       NaN                    NaN
# 1  finmb_369991357                       NaN                    NaN
# 2    finmb_3103130                       NaN                    NaN
#
#    mostRecentQuarter  navPrice  netIncomeToCommon  nextFiscalYearEnd  \
# 0       1.659226e+09       NaN       1.328000e+09       1.698710e+09
# 1       1.656547e+09       NaN       9.630000e+08       1.703981e+09
# 2       1.104451e+09       NaN      -3.235942e+06       1.167523e+09
#
#    numberOfAnalystOpinions     open  openInterest  operatingCashflow  \
# 0                      NaN  132.120           NaN       1.305000e+09
# 1                     12.0   44.570           NaN       1.570000e+09
# 2                      NaN    0.052           NaN      -2.015017e+06
#
#    operatingMargins  payoutRatio  pegRatio         phone  preMarketPrice  \
# 0           0.23938       0.1881      2.31  800 227 9770             NaN
# 1           0.21694       0.0584      0.03  412 315 2900             NaN
# 2         -60.92313          NaN       NaN  702 866 9054             NaN
#
#    previousClose  priceHint  priceToBook  priceToSalesTrailing12Months  \
# 0        133.160        2.0     7.557016                      5.774556
# 1         43.140        2.0     1.348322                      0.570717
# 2          0.051        4.0    52.000000                    423.848970
#
#    profitMargins  quickRatio quoteType recommendationKey  recommendationMean  \
# 0        0.19943       1.273    EQUITY              none                 NaN
# 1        0.07194       0.822    EQUITY               buy                 2.1
# 2        0.00000       3.309    EQUITY              none                 NaN
#
#    regularMarketDayHigh  regularMarketDayLow  regularMarketOpen  \
# 0              132.1300               128.29            132.120
# 1               43.7600                41.61             44.570
# 2                0.0544                 0.05              0.052
#
#    regularMarketPreviousClose  regularMarketPrice  regularMarketVolume  \
# 0                     133.160             129.890            2154507.0
# 1                      43.140              42.460           11298962.0
# 2                       0.051               0.052            9534423.0
#
#    returnOnAssets  returnOnEquity  revenueGrowth  revenuePerShare  \
# 0         0.09499         0.26462          0.083           22.178
# 1         0.12041         0.19323          0.286           72.553
# 2        -1.67797       -13.62085            NaN            0.001
#
#    revenueQuarterlyGrowth           sector  sharesOutstanding  \
# 0                     NaN       Healthcare        296040992.0
# 1                     NaN  Basic Materials        179924992.0
# 2                     NaN  Basic Materials        411647008.0
#
#    sharesPercentSharesOut  sharesShort  sharesShortPreviousMonthDate  \
# 0                  0.0091    2705705.0                  1.659053e+09
# 1                  0.0607   10927858.0                  1.659053e+09
# 2                     NaN          NaN                           NaN
#
#    sharesShortPriorMonth                   shortName  shortPercentOfFloat  \
# 0              3011237.0  Agilent Technologies, Inc.               0.0092
# 1              7558219.0           Alcoa Corporation               0.0685
# 2                    NaN          ASIA BROADBAND INC                  NaN
#
#    shortRatio  startDate state  strikePrice symbol  targetHighPrice  \
# 0        1.94        NaN    CA          NaN      A              NaN
# 1        2.20        NaN    PA          NaN     AA             75.0
# 2         NaN        NaN    NV          NaN   AABB              NaN
#
#    targetLowPrice  targetMeanPrice  targetMedianPrice  threeYearAverageReturn  \
# 0             NaN              NaN                NaN                     NaN
# 1            45.0            58.22               55.5                     NaN
# 2             NaN              NaN                NaN                     NaN
#
#    toCurrency  totalAssets     totalCash  totalCashPerShare     totalDebt  \
# 0         NaN          NaN  1.077000e+09              3.638  3.073000e+09
# 1         NaN          NaN  1.638000e+09              9.104  1.813000e+09
# 2         NaN          NaN  1.116677e+06              0.028  8.708090e+05
#
#    totalRevenue  tradeable  trailingAnnualDividendRate  \
# 0  6.659000e+09        NaN                       0.824
# 1  1.338600e+10        NaN                       0.300
# 2  5.050300e+04        NaN                       0.000
#
#    trailingAnnualDividendYield  trailingEps  trailingPE  trailingPegRatio  \
# 0                     0.006188        4.380    29.65525            2.2062
# 1                     0.006954        5.140     8.26070               NaN
# 2                     0.000000       -0.093         NaN               NaN
#
#    twoHundredDayAverage      volume  volume24Hr  volumeAllCurrencies  \
# 0            132.666700   2154507.0         NaN                  NaN
# 1             61.461700  11298962.0         NaN                  NaN
# 2              0.094607   9534423.0         NaN                  NaN
#
#                         website  yield  ytdReturn         zip
# 0       https://www.agilent.com    NaN        NaN       95051
# 1         https://www.alcoa.com    NaN        NaN  15212-5858
# 2  https://asiabroadbandinc.com    NaN        NaN  89169-2930

# %%
df.to_excel("data/stock_info.xlsx", sheet_name=SHEET_NAME_STOCK_INFO, index=False, header=True)

# %%
# Stock stats
len(stock_stats), len(stock_stats["symbol"].unique())
# Out:
# (8267, 8267)

# %% [markdown]
# # Data Cleansing

# %%
FROM_FILE = "data/alphalib_united_states_6.xlsx"
TO_FILE = "data/alphalib_united_states_new.xlsx"

stock_info_1 = pd.read_excel(TO_FILE, sheet_name=SHEET_NAME_STOCK_INFO, engine="openpyxl")
stock_info_2 = pd.read_excel(FROM_FILE, sheet_name=SHEET_NAME_STOCK_INFO, engine="openpyxl")
print(len(stock_info_1.columns), len(stock_info_2.columns))
# Out:
# 156 154

# %%
def create_missing_cols(df, target_cols):
    columns = df.columns.tolist()
    missing_cols = list(set(target_cols) - set(columns))
    df[missing_cols] = None

# %%
# Create missing columns for stock_info
print("Create missing columns")
if len(stock_info_1.columns) > len(stock_info_2.columns):
    stock_info_columns = stock_info_1.columns.tolist()
    stock_info_columns.sort()
    create_missing_cols(stock_info_2, stock_info_columns)
    stock_info_2 = stock_info_2[stock_info_columns]
    print(len(stock_info_1.columns), len(stock_info_2.columns))
elif len(stock_info_1.columns) < len(stock_info_2.columns):
    stock_info_columns = stock_info_2.columns.tolist()
    stock_info_columns.sort()
    create_missing_cols(stock_info_1, stock_info_columns)
    stock_info_1 = stock_info_1[stock_info_columns]
    print(len(stock_info_1.columns), len(stock_info_2.columns))
else:
    print("No action required")
    print(len(stock_info_1.columns), len(stock_info_2.columns))
    
# Remove overlapped stocks
print("Remove overlapped stocks")
filter = ~stock_info_2["symbol"].isin(stock_info_1["symbol"].tolist()) 
print(len(stock_info_2),len(stock_info_2[filter]))
stock_info_2 = stock_info_2[filter]
# Out:
# Create missing columns
# 156 156
# Remove overlapped stocks
# 223 216

# %%
# Merge the 2 data frames
stock_info_all = pd.concat([stock_info_1, stock_info_2], ignore_index=True)
print(len(stock_info_all))
# Out:
# 3786

# %%
# Clean up stock_dividends
stock_dividends_1 = pd.read_excel(TO_FILE, sheet_name=SHEET_NAME_STOCK_DIVIDENDS, engine="openpyxl")
stock_dividends_2 = pd.read_excel(FROM_FILE, sheet_name=SHEET_NAME_STOCK_DIVIDENDS, engine="openpyxl")
print(len(stock_dividends_1.columns), len(stock_dividends_2.columns))

print(stock_dividends_1.columns)
print(stock_dividends_2.columns)

cols_1 = stock_dividends_1.columns.tolist()
cols_1.sort()

cols_2 = stock_dividends_2.columns.tolist()
cols_2.sort()

if (cols_1 == cols_2):
    print("Same columns")
else:
    print("!!!!!!!!!!! Not the same ")
    if len(stock_dividends_1.columns) > len(stock_dividends_2.columns):
        stock_dividends_columns = stock_dividends_1.columns.tolist()
        stock_dividends_columns.sort()
        create_missing_cols(stock_dividends_2, stock_dividends_columns)
        stock_dividends_2 = stock_dividends_2[stock_dividends_columns]
        print(len(stock_dividends_1.columns), len(stock_dividends_2.columns))
    elif len(stock_dividends_1.columns) < len(stock_dividends_2.columns):
        stock_dividends_columns = stock_dividends_2.columns.tolist()
        stock_dividends_columns.sort()
        create_missing_cols(stock_dividends_1, stock_dividends_columns)
        stock_dividends_1 = stock_dividends_1[stock_dividends_columns]
        print(len(stock_dividends_1.columns), len(stock_dividends_2.columns))
# Out:
# 9 6
# Index(['Country', 'Date', 'Dividend', 'Full Name', 'Name', 'Payment Date',
#        'Symbol', 'Type', 'Yield'],
#       dtype='object')
# Index(['Country', 'Date', 'Dividends', 'Full Name', 'Name', 'Symbol'], dtype='object')
# !!!!!!!!!!! Not the same
# 9 9

# %%
print("Remove overlapped stocks")
filter = ~stock_dividends_2["Symbol"].isin(stock_dividends_1["Symbol"].tolist()) 
print(len(stock_dividends_2), len(stock_dividends_2[filter]))
stock_dividends_2 = stock_dividends_2[filter]

# Merge the 2 data frames
stock_dividends_all = pd.concat([stock_dividends_1, stock_dividends_2], ignore_index=True)
print(len(stock_dividends_all))
print(len(stock_dividends_1), len(stock_dividends_2))
# Out:
# Remove overlapped stocks
# 3770 3728
# 56043
# 52315 3728

# %%
# Clean up stock_financials
stock_financials_1 = pd.read_excel(TO_FILE, sheet_name=SHEET_NAME_STOCK_FINANCIALS, engine="openpyxl")
stock_financials_2 = pd.read_excel(FROM_FILE, sheet_name=SHEET_NAME_STOCK_FINANCIALS, engine="openpyxl")
print(len(stock_financials_1.columns), len(stock_financials_2.columns))

cols_1 = stock_financials_1.columns.tolist()
cols_1.sort()

cols_2 = stock_financials_2.columns.tolist()
cols_2.sort()

if (cols_1 == cols_2):
    print("Same columns")
    print(cols_1)
else:
    print("!!!!!!!!!!! Not the same ")
    if len(stock_financials_1.columns) > len(stock_financials_2.columns):
        stock_financials_columns = stock_financials_1.columns.tolist()
        stock_financials_columns.sort()
        create_missing_cols(stock_financials_2, stock_financials_columns)
        stock_financials_2 = stock_financials_2[stock_financials_columns]
        print(len(stock_financials_1.columns), len(stock_financials_2.columns))
    elif len(stock_financials_1.columns) < len(stock_financials_2.columns):
        stock_financials_columns = stock_financials_2.columns.tolist()
        stock_financials_columns.sort()
        create_missing_cols(stock_financials_1, stock_financials_columns)
        stock_financials_1 = stock_financials_1[stock_financials_columns]
        print(len(stock_financials_1.columns), len(stock_financials_2.columns))
# Out:
# 27 27
# Same columns
# ['Cost Of Revenue', 'Country', 'Date', 'Discontinued Operations', 'Ebit', 'Effect Of Accounting Charges', 'Extraordinary Items', 'Full Name', 'Gross Profit', 'Income Before Tax', 'Income Tax Expense', 'Interest Expense', 'Minority Interest', 'Name', 'Net Income', 'Net Income Applicable To Common Shares', 'Net Income From Continuing Ops', 'Non Recurring', 'Operating Income', 'Other Items', 'Other Operating Expenses', 'Research Development', 'Selling General Administrative', 'Symbol', 'Total Operating Expenses', 'Total Other Income Expense Net', 'Total Revenue']

# %%
print("Remove overlapped stocks")
filter = ~stock_financials_2["Symbol"].isin(stock_financials_1["Symbol"].tolist()) 
print(len(stock_financials_2), len(stock_financials_2[filter]))
stock_financials_2 = stock_financials_2[filter]

# Merge the 2 data frames
stock_financials_all = pd.concat([stock_financials_1, stock_financials_2], ignore_index=True)
print(len(stock_financials_all))
print(len(stock_financials_1), len(stock_financials_2))
# Out:
# Remove overlapped stocks
# 903 875
# 15208
# 14333 875

# %%
# Save to new file
with pd.ExcelWriter(TO_FILE) as writer:  
    stock_info_all.to_excel(writer,sheet_name=SHEET_NAME_STOCK_INFO, header=True, index=False)
    stock_dividends_all.to_excel(writer,sheet_name=SHEET_NAME_STOCK_DIVIDENDS, header=True, index=False)
    stock_financials_all.to_excel(writer,sheet_name=SHEET_NAME_STOCK_FINANCIALS, header=True, index=False)

# %%
# validate the data
stock_info_new = pd.read_excel(TO_FILE, sheet_name=SHEET_NAME_STOCK_INFO, engine="openpyxl")
print(len(stock_info_new))
# Out:
# 3786
