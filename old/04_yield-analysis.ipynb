# %%
from IPython.core.interactiveshell import InteractiveShell
from IPython.display import display
InteractiveShell.ast_node_interactivity = "all"

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import time
from datetime import datetime, timezone

# %%
# %matplotlib inline
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_seq_items', 500)
pd.set_option("display.max_colwidth", None)

# %% [markdown]
# # Analyse High-Yield Dividend Stocks

# %%
from alphalib.analysis.dividend_yield import recommend_stocks
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/alpha2phi/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
rec_stocks = recommend_stocks()
# Out:
# 2022-10-25 11:39:15,952 - [ dividend_yield.py:54 - recommend_stocks() - INFO ] Analyze stocks by sector
# 2022-10-25 11:39:15,965 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for SPH
# 2022-10-25 11:39:22,700 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for MINDP
# 2022-10-25 11:39:28,557 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for IVR
# 2022-10-25 11:39:33,797 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for ORC
# 2022-10-25 11:39:37,802 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for WMC
# 2022-10-25 11:39:42,248 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for BVERS
# 2022-10-25 11:40:05,372 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for BVERS
# 2022-10-25 11:40:05,704 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for MITT
# 2022-10-25 11:40:11,025 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for NYMT
# 2022-10-25 11:40:15,102 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for CHMI
# 2022-10-25 11:40:19,667 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for ARR
# 2022-10-25 11:40:23,561 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for MFA
# 2022-10-25 11:40:27,904 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for EARN
# 2022-10-25 11:40:31,868 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for CIM
# 2022-10-25 11:40:36,089 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for TWO
# 2022-10-25 11:40:40,297 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for ARI
# 2022-10-25 11:40:44,303 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for NLY
# 2022-10-25 11:40:48,420 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for AGNC
# 2022-10-25 11:40:52,468 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for DX
# 2022-10-25 11:40:56,579 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for RC
# 2022-10-25 11:41:00,853 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for OPI
# 2022-10-25 11:41:04,863 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for LFT
# 2022-10-25 11:41:09,264 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for GNL
# 2022-10-25 11:41:13,822 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for SACH
# 2022-10-25 11:41:17,711 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for PMT
# 2022-10-25 11:41:40,816 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for PMT
# 2022-10-25 11:41:41,265 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for ACR-PC
# 2022-10-25 11:42:07,800 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for ACR-PC
# 2022-10-25 11:42:08,146 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for CWPS
# 2022-10-25 11:42:32,166 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for CWPS
# 2022-10-25 11:42:32,494 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for USDP
# 2022-10-25 11:42:36,578 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for IEP
# 2022-10-25 11:42:41,281 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for MMTRS
# 2022-10-25 11:43:04,241 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for MMTRS
# 2022-10-25 11:43:04,582 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for MTBCP
# 2022-10-25 11:43:27,847 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for MTBCP
# 2022-10-25 11:43:28,189 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for CEN
# 2022-10-25 11:43:32,907 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for NTG
# 2022-10-25 11:43:38,028 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for FMO
# 2022-10-25 11:44:02,576 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for FMO
# 2022-10-25 11:44:02,932 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for CLM
# 2022-10-25 11:44:07,231 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for CRF
# 2022-10-25 11:44:11,385 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for OXLC
# 2022-10-25 11:44:15,139 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for GER
# 2022-10-25 11:44:18,917 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for GECC
# 2022-10-25 11:44:23,538 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for EDF
# 2022-10-25 11:44:46,964 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for EDF
# 2022-10-25 11:44:48,373 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for OXSQ
# 2022-10-25 11:44:54,303 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for EDI
# 2022-10-25 11:45:17,548 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for EDI
# 2022-10-25 11:45:17,951 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for ICMB
# 2022-10-25 11:45:22,192 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for FCRD
# 2022-10-25 11:45:26,912 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for EMO
# 2022-10-25 11:45:30,341 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for FSK
# 2022-10-25 11:45:34,028 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for OFS
# 2022-10-25 11:45:38,694 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for BKCC
# 2022-10-25 11:45:42,130 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for RIV
# 2022-10-25 11:45:45,348 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for OPP
# 2022-10-25 11:45:49,328 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for FTF
# 2022-10-25 11:45:53,710 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for MRCC
# 2022-10-25 11:45:58,624 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for VGI
# 2022-10-25 11:46:02,940 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for FGB
# 2022-10-25 11:46:06,461 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for ACV
# 2022-10-25 11:46:29,699 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for ACV
# 2022-10-25 11:46:30,140 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for GLV
# 2022-10-25 11:46:34,104 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for RA
# 2022-10-25 11:46:39,566 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for GLO
# 2022-10-25 11:46:44,080 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for JQC
# 2022-10-25 11:46:55,990 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for FEN
# 2022-10-25 11:46:59,979 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for NCV
# 2022-10-25 11:47:04,814 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for FPL
# 2022-10-25 11:47:28,105 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for FPL
# 2022-10-25 11:47:28,513 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for NCZ
# 2022-10-25 11:47:32,334 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for GOF
# 2022-10-25 11:47:55,203 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for GOF
# 2022-10-25 11:47:56,588 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for PSEC
# 2022-10-25 11:48:01,763 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for FEI
# 2022-10-25 11:48:05,642 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for GLQ
# 2022-10-25 11:48:28,872 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for GLQ
# 2022-10-25 11:48:29,311 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for GGN
# 2022-10-25 11:48:33,293 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for AFSIM
# 2022-10-25 11:48:55,880 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for AFSIM
# 2022-10-25 11:48:56,218 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for CUBA
# 2022-10-25 11:49:00,215 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for AFSIC
# 2022-10-25 11:49:23,361 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for AFSIC
# 2022-10-25 11:49:23,676 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for PHK
# 2022-10-25 11:49:28,106 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for DMO
# 2022-10-25 11:49:32,001 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for EOD
# 2022-10-25 11:49:56,087 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for EOD
# 2022-10-25 11:49:56,523 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for AFSIP
# 2022-10-25 11:50:19,495 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for AFSIP
# 2022-10-25 11:50:19,821 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for PNNT
# 2022-10-25 11:50:24,420 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for TPVG
# 2022-10-25 11:50:28,225 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for AFSIB
# 2022-10-25 11:50:51,130 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for AFSIB
# 2022-10-25 11:50:51,463 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for SRV
# 2022-10-25 11:50:57,367 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for TTP
# 2022-10-25 11:51:01,465 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for WHF
# 2022-10-25 11:51:05,735 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for HIE
# 2022-10-25 11:51:09,810 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for EFC
# 2022-10-25 11:51:13,806 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for HTY
# 2022-10-25 11:51:36,884 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for HTY
# 2022-10-25 11:51:37,335 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for CGBD
# 2022-10-25 11:51:41,195 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for TCPC
# 2022-10-25 11:51:45,364 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for PGP
# 2022-10-25 11:52:08,311 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for PGP
# 2022-10-25 11:52:08,770 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for NMFC
# 2022-10-25 11:52:12,443 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for FEO
# 2022-10-25 11:52:35,372 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for FEO
# 2022-10-25 11:52:35,842 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for SCM
# 2022-10-25 11:52:39,962 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for AFSIA
# 2022-10-25 11:53:02,847 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for AFSIA
# 2022-10-25 11:53:03,182 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for MCN
# 2022-10-25 11:53:07,528 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for SZC
# 2022-10-25 11:53:30,357 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for SZC
# 2022-10-25 11:53:30,802 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for HEQ
# 2022-10-25 11:53:53,681 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for HEQ
# 2022-10-25 11:53:54,104 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for FDUS
# 2022-10-25 11:53:59,220 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for USA
# 2022-10-25 11:54:03,385 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for BCV
# 2022-10-25 11:54:07,104 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for DPG
# 2022-10-25 11:54:11,339 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for NEWT
# 2022-10-25 11:54:15,133 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for NRO
# 2022-10-25 11:54:38,041 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for NRO
# 2022-10-25 11:54:38,493 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for ERC
# 2022-10-25 11:54:43,458 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for MFD
# 2022-10-25 11:54:47,862 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for CHKR
# 2022-10-25 11:55:12,168 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for CHKR
# 2022-10-25 11:55:12,507 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for ECTM
# 2022-10-25 11:55:35,287 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for ECTM
# 2022-10-25 11:55:35,620 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for MMLP
# 2022-10-25 11:55:39,857 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for MVO
# 2022-10-25 11:55:43,493 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for TTYP
# 2022-10-25 11:56:06,165 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for TTYP
# 2022-10-25 11:56:06,491 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for USAC
# 2022-10-25 11:56:30,745 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for USAC
# 2022-10-25 11:56:31,213 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for VOC
# 2022-10-25 11:56:44,160 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for SRLP
# 2022-10-25 11:57:07,448 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for SRLP
# 2022-10-25 11:57:07,884 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for PVL
# 2022-10-25 11:57:12,178 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for ENLC
# 2022-10-25 11:57:35,731 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for ENLC
# 2022-10-25 11:57:36,195 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for NS
# 2022-10-25 11:57:40,102 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for CAPL
# 2022-10-25 11:57:43,533 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for DCP
# 2022-10-25 11:57:47,539 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for PBFX
# 2022-10-25 11:57:51,157 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for AM
# 2022-10-25 11:57:54,756 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for GLP
# 2022-10-25 11:58:18,833 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for GLP
# 2022-10-25 11:58:19,406 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for GEL
# 2022-10-25 11:58:23,464 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for SUN
# 2022-10-25 11:58:27,318 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for CEQP
# 2022-10-25 11:58:31,273 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for GPP
# 2022-10-25 11:58:35,268 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for DKL
# 2022-10-25 11:58:39,305 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for WES
# 2022-10-25 11:59:02,501 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for WES
# 2022-10-25 11:59:02,954 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for SHLX
# 2022-10-25 11:59:27,219 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for SHLX
# 2022-10-25 11:59:27,703 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for DMLP
# 2022-10-25 11:59:50,808 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for DMLP
# 2022-10-25 11:59:51,271 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for FCNE
# 2022-10-25 12:00:14,181 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for FCNE
# 2022-10-25 12:00:14,516 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for NCMI
# 2022-10-25 12:00:18,800 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for LUMN
# 2022-10-25 12:00:23,510 - [ dividend_yield.py:81 - recommend_stocks() - INFO ] Getting info for MSB
# 2022-10-25 12:00:29,027 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for PBR
# 2022-10-25 12:00:32,910 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for PBR-A
# 2022-10-25 12:00:56,467 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for PBR-A
# 2022-10-25 12:00:56,927 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for SNPTY
# 2022-10-25 12:01:20,170 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for SNPTY
# 2022-10-25 12:01:20,490 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for AMKBY
# 2022-10-25 12:01:43,416 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for AMKBY
# 2022-10-25 12:01:44,683 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for ISNPY
# 2022-10-25 12:02:07,791 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for ISNPY
# 2022-10-25 12:02:08,132 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for NRDBY
# 2022-10-25 12:02:31,358 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for NRDBY
# 2022-10-25 12:02:31,883 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for ELP
# 2022-10-25 12:02:55,480 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for ELP
# 2022-10-25 12:02:55,946 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for NLY
# 2022-10-25 12:03:00,319 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for BAK
# 2022-10-25 12:03:04,296 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for AGNC
# 2022-10-25 12:03:08,585 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for ZIM
# 2022-10-25 12:03:12,710 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for SBLK
# 2022-10-25 12:03:16,093 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for CCU
# 2022-10-25 12:03:20,913 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for GOGL
# 2022-10-25 12:03:25,535 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for CLM
# 2022-10-25 12:03:30,119 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for CIM
# 2022-10-25 12:03:33,957 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for PMT
# 2022-10-25 12:03:57,047 - [ nasdaq.py:45 - get_stock_details() - WARNING ] Unable to get details for PMT
# 2022-10-25 12:03:57,494 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for HIMX
# 2022-10-25 12:04:01,993 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for MFA
# 2022-10-25 12:04:06,489 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for CRF
# 2022-10-25 12:04:10,853 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for BRMK
# 2022-10-25 12:04:15,320 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for EGLE
# 2022-10-25 12:04:19,431 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for LPG
# 2022-10-25 12:04:23,521 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for SJT
# 2022-10-25 12:04:27,620 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for ECC
# 2022-10-25 12:04:32,292 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for IVR
# 2022-10-25 12:04:36,366 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for ORC
# 2022-10-25 12:04:40,548 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for BPT
# 2022-10-25 12:04:44,594 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for GLO
# 2022-10-25 12:04:48,491 - [ dividend_yield.py:99 - recommend_stocks() - INFO ] Getting info for CHMI

# %%
for s in rec_stocks:
    df = s.to_df()
    
    display(df)
    print("\n")
    print(s.yfinance_url)
    display(df[["sector", "trailing_annual_dividend_yield", "dividend_yield_pct", "earnings_date", "current_price", "fifty_two_week_low", "fifty_two_week_high", "sentiment_score"]].T)
    display(s.dividend_history.head(10))
    
    print("\n\n\n")
# Out:
#                   label symbol ex_dividend_date  dividend_yield_pct  \
# 0  ZIM Dividend History    ZIM       2022-08-26               46.28
#
#    annual_dividend  pe_ratio  \
# 0             19.0      0.47
#
#                                                            nasdaq_url  \
# 0  https://www.nasdaq.com/market-activity/stocks/zim/dividend-history
#
#                               name exchange       sector  beta  current_price  \
# 0  ZIM Integrated Shipping Service      NYQ  Industrials  None          24.09
#
#    fifty_two_week_low  fifty_two_week_high five_year_avg_dividend_yield  \
# 0               22.53                91.23                         None
#
#         earnings_date       dividend_date  last_dividend_date  forward_eps  \
# 0 2022-11-15 21:30:00 2022-09-08 08:00:00 2022-08-26 08:00:00         8.06
#
#    forward_pe  trailing_eps  trailing_pe  peg_ratio  price_to_book  \
# 0    2.988834         51.72     0.465777      -0.01       0.551688
#
#    free_cash_flow  return_on_equity  debt_to_equity  \
# 0      4778290176           1.78513          86.713
#
#    price_to_sales_trailing_12_months  payout_ratio  dividend_yield  \
# 0                           0.210359        0.4321          1.1488
#
#    dividend_rate  trailing_annual_dividend_rate  \
# 0           27.1                           27.1
#
#    trailing_annual_dividend_yield  \
# 0                        1.148792
#
#                                                yfinance_url  sentiment_score  \
# 0  https://finance.yahoo.com/quote/ZIM/key-statistics?p=ZIM         0.084369
#
#           source                             info_url
# 0  yahoo_finance  https://seekingalpha.com/symbol/ZIM
# https://finance.yahoo.com/quote/ZIM/key-statistics?p=ZIM
#                                                   0
# sector                                  Industrials
# trailing_annual_dividend_yield             1.148792
# dividend_yield_pct                            46.28
# earnings_date                   2022-11-15 21:30:00
# current_price                                 24.09
# fifty_two_week_low                            22.53
# fifty_two_week_high                           91.23
# sentiment_score                            0.084369
#   ex_eff_date  type  cash_amount declaration_date record_date payment_date
# 0  2022-08-26  CASH         4.75       2022-08-17  2022-08-29   2022-09-08
# 1  2022-05-27  CASH         2.85       2022-05-18  2022-05-31   2022-06-08
# 2  2022-03-22  CASH        17.00       2022-03-09  2022-03-23   2022-04-04
# 3  2021-12-15  CASH         2.50       2021-11-17  2021-12-16   2021-12-27
# 4  2021-08-24  CASH         2.00       2021-05-19  2021-08-25   2021-09-15
#                    label symbol ex_dividend_date  dividend_yield_pct  \
# 0  NCMI Dividend History   NCMI       2022-08-19                29.7
#
#    annual_dividend  pe_ratio  \
# 0             0.12       0.0
#
#                                                             nasdaq_url  \
# 0  https://www.nasdaq.com/market-activity/stocks/ncmi/dividend-history
#
#                        name exchange                  sector      beta  \
# 0  National CineMedia, Inc.      NMS  Communication Services  1.927781
#
#    current_price  fifty_two_week_low  fifty_two_week_high  \
# 0            0.4              0.3915                 3.93
#
#    five_year_avg_dividend_yield       earnings_date       dividend_date  \
# 0                         11.42 2022-11-07 18:59:00 2022-09-06 08:00:00
#
#    last_dividend_date  forward_eps  forward_pe  trailing_eps trailing_pe  \
# 0 2022-08-19 08:00:00         0.08           5        -0.677        None
#
#    peg_ratio price_to_book  free_cash_flow return_on_equity debt_to_equity  \
# 0       0.26          None       -47200000             None           None
#
#    price_to_sales_trailing_12_months payout_ratio  dividend_yield  \
# 0                           0.165265         None          0.2862
#
#    dividend_rate  trailing_annual_dividend_rate  \
# 0           0.12                           0.16
#
#    trailing_annual_dividend_yield  \
# 0                         0.39604
#
#                                                  yfinance_url  \
# 0  https://finance.yahoo.com/quote/NCMI/key-statistics?p=NCMI
#
#    sentiment_score   source                              info_url
# 0        -0.036075  dataset  https://seekingalpha.com/symbol/NCMI
# https://finance.yahoo.com/quote/NCMI/key-statistics?p=NCMI
#                                                      0
# sector                          Communication Services
# trailing_annual_dividend_yield                 0.39604
# dividend_yield_pct                                29.7
# earnings_date                      2022-11-07 18:59:00
# current_price                                      0.4
# fifty_two_week_low                              0.3915
# fifty_two_week_high                               3.93
# sentiment_score                              -0.036075
#   ex_eff_date  type  cash_amount declaration_date record_date payment_date
# 0  2022-08-19  CASH         0.03       2022-08-08  2022-08-22   2022-09-06
# 1  2022-05-20  CASH         0.03       2022-05-09  2022-05-23   2022-06-07
# 2  2022-03-16  CASH         0.05       2022-03-03  2022-03-17   2022-03-31
# 3  2021-11-19  CASH         0.05       2021-11-08  2021-11-22   2021-12-07
# 4  2021-08-20  CASH         0.05       2021-08-09  2021-08-23   2021-09-06
# 5  2021-05-20  CASH         0.05       2021-05-10  2021-05-21   2021-06-07
# 6  2021-03-19  CASH         0.05       2021-03-08  2021-03-22   2021-04-05
# 7  2020-11-13  CASH         0.07       2020-11-02  2020-11-16   2020-12-01
# 8  2020-08-14  CASH         0.07       2020-08-03  2020-08-17   2020-08-31
# 9  2020-05-15  CASH         0.07       2020-05-05  2020-05-18   2020-06-01
#                   label symbol ex_dividend_date  dividend_yield_pct  \
# 0  ORC Dividend History    ORC       2022-09-29               23.36
#
#    annual_dividend  pe_ratio  \
# 0             1.92       0.0
#
#                                                            nasdaq_url  \
# 0  https://www.nasdaq.com/market-activity/stocks/orc/dividend-history
#
#                           name exchange       sector      beta  current_price  \
# 0  Orchid Island Capital, Inc.      NYQ  Real Estate  1.488577           9.51
#
#    fifty_two_week_low  fifty_two_week_high  five_year_avg_dividend_yield  \
# 0                7.95                 25.2                         18.36
#
#         earnings_date       dividend_date  last_dividend_date  forward_eps  \
# 0 2022-10-28 04:00:00 2022-11-28 08:00:00 2022-09-29 08:00:00          2.6
#
#    forward_pe  trailing_eps trailing_pe peg_ratio  price_to_book  \
# 0    3.657692         -1.28        None      None       0.662026
#
#   free_cash_flow  return_on_equity  debt_to_equity  \
# 0           None          -0.42897         750.959
#
#    price_to_sales_trailing_12_months payout_ratio  dividend_yield  \
# 0                          -1.530959         None           0.199
#
#    dividend_rate  trailing_annual_dividend_rate  \
# 0           1.92                            3.4
#
#    trailing_annual_dividend_yield  \
# 0                        0.352332
#
#                                                yfinance_url  sentiment_score  \
# 0  https://finance.yahoo.com/quote/ORC/key-statistics?p=ORC         0.012755
#
#     source                             info_url
# 0  dataset  https://seekingalpha.com/symbol/ORC
# https://finance.yahoo.com/quote/ORC/key-statistics?p=ORC
#                                                   0
# sector                                  Real Estate
# trailing_annual_dividend_yield             0.352332
# dividend_yield_pct                            23.36
# earnings_date                   2022-10-28 04:00:00
# current_price                                  9.51
# fifty_two_week_low                             7.95
# fifty_two_week_high                            25.2
# sentiment_score                            0.012755
#   ex_eff_date  type  cash_amount declaration_date record_date payment_date
# 0  2022-09-29  CASH        0.160       2022-09-12  2022-09-30   2022-10-27
# 1  2022-08-30  CASH        0.160       2022-08-17  2022-08-31   2022-09-28
# 2  2022-07-28  CASH        0.045       2022-07-13  2022-07-29   2022-08-29
# 3  2022-06-29  CASH        0.045       2022-06-14  2022-06-30   2022-07-27
# 4  2022-05-27  CASH        0.045       2022-05-11  2022-05-31   2022-06-28
# 5  2022-04-28  CASH        0.045       2022-04-13  2022-04-29   2022-05-27
# 6  2022-03-30  CASH        0.045       2022-03-16  2022-03-31   2022-04-27
# 7  2022-02-25  CASH        0.055       2022-02-16  2022-02-28   2022-03-29
# 8  2022-01-28  CASH        0.055       2022-01-13  2022-01-31   2022-02-24
# 9  2021-12-30  CASH        0.065       2021-12-09  2021-12-31   2022-01-27
#                   label symbol ex_dividend_date  dividend_yield_pct  \
# 0  ORC Dividend History    ORC       2022-09-29               23.36
#
#    annual_dividend  pe_ratio  \
# 0             1.92       0.0
#
#                                                            nasdaq_url  \
# 0  https://www.nasdaq.com/market-activity/stocks/orc/dividend-history
#
#                           name exchange       sector      beta  current_price  \
# 0  Orchid Island Capital, Inc.      NYQ  Real Estate  1.488577           9.51
#
#    fifty_two_week_low  fifty_two_week_high  five_year_avg_dividend_yield  \
# 0                7.95                 25.2                         18.36
#
#         earnings_date       dividend_date  last_dividend_date  forward_eps  \
# 0 2022-10-28 04:00:00 2022-11-28 08:00:00 2022-09-29 08:00:00          2.6
#
#    forward_pe  trailing_eps trailing_pe peg_ratio  price_to_book  \
# 0    3.657692         -1.28        None      None       0.662026
#
#   free_cash_flow  return_on_equity  debt_to_equity  \
# 0           None          -0.42897         750.959
#
#    price_to_sales_trailing_12_months payout_ratio  dividend_yield  \
# 0                          -1.530959         None           0.199
#
#    dividend_rate  trailing_annual_dividend_rate  \
# 0           1.92                            3.4
#
#    trailing_annual_dividend_yield  \
# 0                        0.352332
#
#                                                yfinance_url  sentiment_score  \
# 0  https://finance.yahoo.com/quote/ORC/key-statistics?p=ORC         0.012755
#
#           source                             info_url
# 0  yahoo_finance  https://seekingalpha.com/symbol/ORC
# https://finance.yahoo.com/quote/ORC/key-statistics?p=ORC
#                                                   0
# sector                                  Real Estate
# trailing_annual_dividend_yield             0.352332
# dividend_yield_pct                            23.36
# earnings_date                   2022-10-28 04:00:00
# current_price                                  9.51
# fifty_two_week_low                             7.95
# fifty_two_week_high                            25.2
# sentiment_score                            0.012755
#   ex_eff_date  type  cash_amount declaration_date record_date payment_date
# 0  2022-09-29  CASH        0.160       2022-09-12  2022-09-30   2022-10-27
# 1  2022-08-30  CASH        0.160       2022-08-17  2022-08-31   2022-09-28
# 2  2022-07-28  CASH        0.045       2022-07-13  2022-07-29   2022-08-29
# 3  2022-06-29  CASH        0.045       2022-06-14  2022-06-30   2022-07-27
# 4  2022-05-27  CASH        0.045       2022-05-11  2022-05-31   2022-06-28
# 5  2022-04-28  CASH        0.045       2022-04-13  2022-04-29   2022-05-27
# 6  2022-03-30  CASH        0.045       2022-03-16  2022-03-31   2022-04-27
# 7  2022-02-25  CASH        0.055       2022-02-16  2022-02-28   2022-03-29
# 8  2022-01-28  CASH        0.055       2022-01-13  2022-01-31   2022-02-24
# 9  2021-12-30  CASH        0.065       2021-12-09  2021-12-31   2022-01-27
#                   label symbol ex_dividend_date  dividend_yield_pct  \
# 0  LPG Dividend History    LPG       2022-08-12               28.55
#
#    annual_dividend  pe_ratio  \
# 0                0      7.09
#
#                                                            nasdaq_url  \
# 0  https://www.nasdaq.com/market-activity/stocks/lpg/dividend-history
#
#               name exchange  sector      beta  current_price  \
# 0  Dorian LPG Ltd.      NYQ  Energy  1.098378          16.02
#
#    fifty_two_week_low  fifty_two_week_high five_year_avg_dividend_yield  \
# 0               10.77                 18.5                         None
#
#         earnings_date       dividend_date  last_dividend_date  forward_eps  \
# 0 2022-11-01 20:30:00 2022-09-02 08:00:00 2022-08-12 08:00:00         1.77
#
#    forward_pe  trailing_eps  trailing_pe  peg_ratio  price_to_book  \
# 0    9.050848          2.26     7.088496       0.52       0.761515
#
#    free_cash_flow  return_on_equity  debt_to_equity  \
# 0       130039400           0.10198          78.575
#
#    price_to_sales_trailing_12_months  payout_ratio  dividend_yield  \
# 0                           2.259372        1.9912           0.353
#
#    dividend_rate  trailing_annual_dividend_rate  \
# 0            5.5                            5.5
#
#    trailing_annual_dividend_yield  \
# 0                        0.348985
#
#                                                yfinance_url  sentiment_score  \
# 0  https://finance.yahoo.com/quote/LPG/key-statistics?p=LPG         0.170667
#
#           source                             info_url
# 0  yahoo_finance  https://seekingalpha.com/symbol/LPG
# https://finance.yahoo.com/quote/LPG/key-statistics?p=LPG
#                                                   0
# sector                                       Energy
# trailing_annual_dividend_yield             0.348985
# dividend_yield_pct                            28.55
# earnings_date                   2022-11-01 20:30:00
# current_price                                 16.02
# fifty_two_week_low                            10.77
# fifty_two_week_high                            18.5
# sentiment_score                            0.170667
#   ex_eff_date  type  cash_amount declaration_date record_date payment_date
# 0  2022-08-12  CASH          1.0       2022-08-03  2022-08-15   2022-09-02
# 1  2022-05-13  CASH          2.5       2022-05-04  2022-05-16   2022-06-02
# 2  2022-01-13  CASH          1.0       2022-01-04  2022-01-14   2022-01-25
# 3  2021-08-06  CASH          1.0       2021-07-30  2021-08-09   2021-09-08
#                    label symbol ex_dividend_date  dividend_yield_pct  \
# 0  SBLK Dividend History   SBLK       2022-08-24               34.29
#
#    annual_dividend  pe_ratio  \
# 0              6.6      2.18
#
#                                                             nasdaq_url  \
# 0  https://www.nasdaq.com/market-activity/stocks/sblk/dividend-history
#
#                        name exchange       sector      beta  current_price  \
# 0  Star Bulk Carriers Corp.      NMS  Industrials  1.053058          18.98
#
#    fifty_two_week_low  fifty_two_week_high five_year_avg_dividend_yield  \
# 0               16.85                33.99                         None
#
#         earnings_date       dividend_date  last_dividend_date  forward_eps  \
# 0 2022-11-17 05:00:00 2022-09-08 08:00:00 2022-08-24 08:00:00         3.88
#
#    forward_pe  trailing_eps  trailing_pe  peg_ratio  price_to_book  \
# 0    4.891752          8.74     2.171625      -0.18       0.925899
#
#    free_cash_flow  return_on_equity  debt_to_equity  \
# 0       663366848           0.46147           67.47
#
#    price_to_sales_trailing_12_months  payout_ratio  dividend_yield  \
# 0                           1.150704        0.6407          0.3403
#
#    dividend_rate  trailing_annual_dividend_rate  \
# 0           6.55                           6.55
#
#    trailing_annual_dividend_yield  \
# 0                         0.34026
#
#                                                  yfinance_url  \
# 0  https://finance.yahoo.com/quote/SBLK/key-statistics?p=SBLK
#
#    sentiment_score         source                              info_url
# 0         0.102407  yahoo_finance  https://seekingalpha.com/symbol/SBLK
# https://finance.yahoo.com/quote/SBLK/key-statistics?p=SBLK
#                                                   0
# sector                                  Industrials
# trailing_annual_dividend_yield              0.34026
# dividend_yield_pct                            34.29
# earnings_date                   2022-11-17 05:00:00
# current_price                                 18.98
# fifty_two_week_low                            16.85
# fifty_two_week_high                           33.99
# sentiment_score                            0.102407
#   ex_eff_date  type  cash_amount declaration_date record_date payment_date
# 0  2022-08-24  CASH         1.65       2022-08-04  2022-08-25   2022-09-08
# 1  2022-06-02  CASH         1.65       2022-05-24  2022-06-03   2022-06-16
# 2  2022-03-01  CASH         2.00       2022-02-16  2022-03-02   2022-03-15
# 3  2021-12-09  CASH         1.25       2021-11-16  2021-12-10   2021-12-22
# 4  2021-08-20  CASH         0.70       2021-08-05  2021-08-23   2021-09-08
# 5  2021-05-27  CASH         0.30       2021-05-19  2021-05-31   2021-06-14
# 6  2020-02-28  CASH         0.05       2020-02-19  2020-03-02   2020-03-12
# 7  2019-11-29  CASH         0.05       2019-11-20  2019-12-02   2019-12-16
#                   label symbol ex_dividend_date  dividend_yield_pct  \
# 0  IVR Dividend History    IVR       2022-10-07               25.17
#
#    annual_dividend  pe_ratio  \
# 0              2.6       0.0
#
#                                                            nasdaq_url  \
# 0  https://www.nasdaq.com/market-activity/stocks/ivr/dividend-history
#
#                            name exchange       sector      beta  \
# 0  INVESCO MORTGAGE CAPITAL INC      NYQ  Real Estate  1.488209
#
#    current_price  fifty_two_week_low  fifty_two_week_high  \
# 0          10.69                 9.6                   34
#
#    five_year_avg_dividend_yield       earnings_date       dividend_date  \
# 0                         18.59 2022-11-03 04:00:00 2022-10-27 08:00:00
#
#    last_dividend_date  forward_eps  forward_pe  trailing_eps trailing_pe  \
# 0 2022-10-07 08:00:00         4.08    2.620098       -11.585        None
#
#    peg_ratio  price_to_book free_cash_flow  return_on_equity  debt_to_equity  \
# 0      -0.15       0.644753           None          -0.29571         343.923
#
#    price_to_sales_trailing_12_months payout_ratio  dividend_yield  \
# 0                          -1.118124         None          0.2425
#
#    dividend_rate  trailing_annual_dividend_rate  \
# 0            2.6                            3.6
#
#    trailing_annual_dividend_yield  \
# 0                        0.335821
#
#                                                yfinance_url  sentiment_score  \
# 0  https://finance.yahoo.com/quote/IVR/key-statistics?p=IVR          0.08456
#
#     source                             info_url
# 0  dataset  https://seekingalpha.com/symbol/IVR
# https://finance.yahoo.com/quote/IVR/key-statistics?p=IVR
#                                                   0
# sector                                  Real Estate
# trailing_annual_dividend_yield             0.335821
# dividend_yield_pct                            25.17
# earnings_date                   2022-11-03 04:00:00
# current_price                                 10.69
# fifty_two_week_low                              9.6
# fifty_two_week_high                              34
# sentiment_score                             0.08456
#   ex_eff_date  type  cash_amount declaration_date record_date payment_date
# 0  2022-10-07  CASH         0.65       2022-09-28  2022-10-11   2022-10-27
# 1  2022-07-08  CASH         0.90       2022-06-27  2022-07-11   2022-07-27
# 2  2022-04-07  CASH         0.09       2022-03-28  2022-04-08   2022-04-27
# 3  2022-01-10  CASH         0.09       2021-12-27  2022-01-11   2022-01-27
# 4  2021-10-08  CASH         0.09       2021-09-28  2021-10-12   2021-10-26
# 5  2021-07-02  CASH         0.09       2021-06-23  2021-07-06   2021-07-27
# 6  2021-04-08  CASH         0.09       2021-03-26  2021-04-09   2021-04-27
# 7  2021-01-11  CASH         0.08       2020-12-28  2021-01-12   2021-01-26
# 8  2020-10-08  CASH         0.05       2020-09-30  2020-10-12   2020-10-27
# 9  2020-07-02  CASH         0.02       2020-06-17  2020-07-06   2020-07-28
#                   label symbol ex_dividend_date  dividend_yield_pct  \
# 0  IVR Dividend History    IVR       2022-10-07               25.17
#
#    annual_dividend  pe_ratio  \
# 0              2.6       0.0
#
#                                                            nasdaq_url  \
# 0  https://www.nasdaq.com/market-activity/stocks/ivr/dividend-history
#
#                            name exchange       sector      beta  \
# 0  INVESCO MORTGAGE CAPITAL INC      NYQ  Real Estate  1.488209
#
#    current_price  fifty_two_week_low  fifty_two_week_high  \
# 0          10.69                 9.6                   34
#
#    five_year_avg_dividend_yield       earnings_date       dividend_date  \
# 0                         18.59 2022-11-03 04:00:00 2022-10-27 08:00:00
#
#    last_dividend_date  forward_eps  forward_pe  trailing_eps trailing_pe  \
# 0 2022-10-07 08:00:00         4.08    2.620098       -11.585        None
#
#    peg_ratio  price_to_book free_cash_flow  return_on_equity  debt_to_equity  \
# 0      -0.15       0.644753           None          -0.29571         343.923
#
#    price_to_sales_trailing_12_months payout_ratio  dividend_yield  \
# 0                          -1.118124         None          0.2425
#
#    dividend_rate  trailing_annual_dividend_rate  \
# 0            2.6                            3.6
#
#    trailing_annual_dividend_yield  \
# 0                        0.335821
#
#                                                yfinance_url  sentiment_score  \
# 0  https://finance.yahoo.com/quote/IVR/key-statistics?p=IVR          0.08456
#
#           source                             info_url
# 0  yahoo_finance  https://seekingalpha.com/symbol/IVR
# https://finance.yahoo.com/quote/IVR/key-statistics?p=IVR
#                                                   0
# sector                                  Real Estate
# trailing_annual_dividend_yield             0.335821
# dividend_yield_pct                            25.17
# earnings_date                   2022-11-03 04:00:00
# current_price                                 10.69
# fifty_two_week_low                              9.6
# fifty_two_week_high                              34
# sentiment_score                             0.08456
#   ex_eff_date  type  cash_amount declaration_date record_date payment_date
# 0  2022-10-07  CASH         0.65       2022-09-28  2022-10-11   2022-10-27
# 1  2022-07-08  CASH         0.90       2022-06-27  2022-07-11   2022-07-27
# 2  2022-04-07  CASH         0.09       2022-03-28  2022-04-08   2022-04-27
# 3  2022-01-10  CASH         0.09       2021-12-27  2022-01-11   2022-01-27
# 4  2021-10-08  CASH         0.09       2021-09-28  2021-10-12   2021-10-26
# 5  2021-07-02  CASH         0.09       2021-06-23  2021-07-06   2021-07-27
# 6  2021-04-08  CASH         0.09       2021-03-26  2021-04-09   2021-04-27
# 7  2021-01-11  CASH         0.08       2020-12-28  2021-01-12   2021-01-26
# 8  2020-10-08  CASH         0.05       2020-09-30  2020-10-12   2020-10-27
# 9  2020-07-02  CASH         0.02       2020-06-17  2020-07-06   2020-07-28
#                    label symbol ex_dividend_date  dividend_yield_pct  \
# 0  GOGL Dividend History   GOGL       2022-09-06               27.87
#
#    annual_dividend  pe_ratio  \
# 0              2.4      2.53
#
#                                                             nasdaq_url  \
# 0  https://www.nasdaq.com/market-activity/stocks/gogl/dividend-history
#
#                          name exchange       sector      beta  current_price  \
# 0  Golden Ocean Group Limited      NMS  Industrials  1.369196           8.63
#
#    fifty_two_week_low  fifty_two_week_high five_year_avg_dividend_yield  \
# 0                7.24                16.46                         None
#
#         earnings_date       dividend_date  last_dividend_date  forward_eps  \
# 0 2022-11-30 18:59:00 2022-09-14 08:00:00 2022-09-06 08:00:00         18.8
#
#    forward_pe  trailing_eps  trailing_pe peg_ratio  price_to_book  \
# 0    0.459043          3.47     2.487032      None       0.894486
#
#    free_cash_flow  return_on_equity  debt_to_equity  \
# 0       446609632           0.36823          69.431
#
#    price_to_sales_trailing_12_months  payout_ratio  dividend_yield  \
# 0                           1.288674        0.7925          0.2867
#
#    dividend_rate  trailing_annual_dividend_rate  \
# 0            2.4                           2.85
#
#    trailing_annual_dividend_yield  \
# 0                         0.33101
#
#                                                  yfinance_url  \
# 0  https://finance.yahoo.com/quote/GOGL/key-statistics?p=GOGL
#
#    sentiment_score         source                              info_url
# 0         0.072032  yahoo_finance  https://seekingalpha.com/symbol/GOGL
# https://finance.yahoo.com/quote/GOGL/key-statistics?p=GOGL
#                                                   0
# sector                                  Industrials
# trailing_annual_dividend_yield              0.33101
# dividend_yield_pct                            27.87
# earnings_date                   2022-11-30 18:59:00
# current_price                                  8.63
# fifty_two_week_low                             7.24
# fifty_two_week_high                           16.46
# sentiment_score                            0.072032
#   ex_eff_date  type  cash_amount     declaration_date record_date  \
# 0  2022-09-06  CASH        0.600  2022-08-25 00:00:00  2022-09-07
# 1  2022-05-31  CASH        0.500  2022-05-19 00:00:00  2022-06-01
# 2  2022-03-02  CASH        0.900  2022-02-16 00:00:00  2022-03-03
# 3  2021-12-08  CASH        0.850  2021-11-24 00:00:00  2021-12-09
# 4  2021-09-09  CASH        0.500  2021-08-26 00:00:00  2021-09-10
# 5  2021-06-02  CASH        0.250  2021-05-20 00:00:00  2021-06-03
# 6  2020-03-05  CASH        0.050  2020-02-18 00:00:00  2020-03-06
# 7  2019-12-02  CASH        0.150  2019-11-21 00:00:00  2019-12-03
# 8  2019-08-29  CASH        0.100  2019-08-15 00:00:00  2019-08-30
# 9  2019-06-05  CASH        0.025  2019-05-22 00:00:00  2019-06-06
#
#           payment_date
# 0  2022-09-14 00:00:00
# 1  2022-06-08 00:00:00
# 2  2022-03-10 00:00:00
# 3  2021-12-16 00:00:00
# 4  2021-09-20 00:00:00
# 5  2021-06-10 00:00:00
# 6  2020-03-19 00:00:00
# 7  2019-12-18 00:00:00
# 8  2019-09-12 00:00:00
# 9  2019-06-20 00:00:00
#                   label symbol ex_dividend_date  dividend_yield_pct  \
# 0  ARR Dividend History    ARR       2022-10-14               25.64
#
#    annual_dividend  pe_ratio  \
# 0              1.2       0.0
#
#                                                            nasdaq_url  \
# 0  https://www.nasdaq.com/market-activity/stocks/arr/dividend-history
#
#                             name exchange       sector      beta  \
# 0  ARMOUR Residential REIT, Inc.      NYQ  Real Estate  1.134856
#
#    current_price  fifty_two_week_low  fifty_two_week_high  \
# 0           4.77                4.38                10.91
#
#    five_year_avg_dividend_yield       earnings_date       dividend_date  \
# 0                         13.09 2022-10-24 18:59:00 2022-10-28 08:00:00
#
#    last_dividend_date  forward_eps  forward_pe  trailing_eps trailing_pe  \
# 0 2022-10-14 08:00:00         1.11    4.297297        -1.544        None
#
#    peg_ratio  price_to_book free_cash_flow  return_on_equity  debt_to_equity  \
# 0      -0.37       0.542354           None          -0.10745         688.456
#
#    price_to_sales_trailing_12_months payout_ratio  dividend_yield  \
# 0                          -8.468199         None          0.2521
#
#    dividend_rate  trailing_annual_dividend_rate  \
# 0            1.2                            1.2
#
#    trailing_annual_dividend_yield  \
# 0                        0.250522
#
#                                                yfinance_url  sentiment_score  \
# 0  https://finance.yahoo.com/quote/ARR/key-statistics?p=ARR         0.272324
#
#     source                             info_url
# 0  dataset  https://seekingalpha.com/symbol/ARR
# https://finance.yahoo.com/quote/ARR/key-statistics?p=ARR
#                                                   0
# sector                                  Real Estate
# trailing_annual_dividend_yield             0.250522
# dividend_yield_pct                            25.64
# earnings_date                   2022-10-24 18:59:00
# current_price                                  4.77
# fifty_two_week_low                             4.38
# fifty_two_week_high                           10.91
# sentiment_score                            0.272324
#   ex_eff_date  type  cash_amount declaration_date record_date payment_date
# 0  2022-10-14  CASH          0.1       2022-09-27  2022-10-17   2022-10-28
# 1  2022-09-14  CASH          0.1       2022-08-24  2022-09-15   2022-09-29
# 2  2022-08-12  CASH          0.1       2022-07-27  2022-08-15   2022-08-29
# 3  2022-07-14  CASH          0.1       2022-06-24  2022-07-15   2022-07-29
# 4  2022-06-14  CASH          0.1       2022-05-23  2022-06-15   2022-06-29
# 5  2022-05-13  CASH          0.1       2022-04-26  2022-05-16   2022-05-27
# 6  2022-04-14  CASH          0.1       2022-03-25  2022-04-18   2022-04-29
# 7  2022-03-14  CASH          0.1       2022-02-15  2022-03-15   2022-03-28
# 8  2022-02-14  CASH          0.1       2022-01-31  2022-02-15   2022-02-28
# 9  2022-01-14  CASH          0.1       2021-12-27  2022-01-18   2022-01-28
#                    label symbol ex_dividend_date  dividend_yield_pct  \
# 0  GECC Dividend History   GECC       2022-09-14               19.05
#
#    annual_dividend  pe_ratio  \
# 0              1.8         0
#
#                                                             nasdaq_url  \
# 0  https://www.nasdaq.com/market-activity/stocks/gecc/dividend-history
#
#                       name exchange              sector      beta  \
# 0  Great Elm Capital Corp.      NGM  Financial Services  1.528371
#
#    current_price  fifty_two_week_low  fifty_two_week_high  \
# 0           9.45                7.98                21.18
#
#    five_year_avg_dividend_yield       earnings_date       dividend_date  \
# 0                         16.91 2022-11-03 20:30:00 2022-09-30 08:00:00
#
#    last_dividend_date  forward_eps  forward_pe  trailing_eps trailing_pe  \
# 0 2022-09-14 08:00:00          1.4        6.75         -6.59        None
#
#   peg_ratio  price_to_book  free_cash_flow  return_on_equity  debt_to_equity  \
# 0      None       0.735981       -22827376          -0.36915          146.07
#
#    price_to_sales_trailing_12_months payout_ratio  dividend_yield  \
# 0                           2.897065         None          0.1927
#
#    dividend_rate  trailing_annual_dividend_rate  \
# 0            1.8                           2.25
#
#    trailing_annual_dividend_yield  \
# 0                        0.238095
#
#                                                  yfinance_url  \
# 0  https://finance.yahoo.com/quote/GECC/key-statistics?p=GECC
#
#    sentiment_score   source                              info_url
# 0         0.335567  dataset  https://seekingalpha.com/symbol/GECC
# https://finance.yahoo.com/quote/GECC/key-statistics?p=GECC
#                                                   0
# sector                           Financial Services
# trailing_annual_dividend_yield             0.238095
# dividend_yield_pct                            19.05
# earnings_date                   2022-11-03 20:30:00
# current_price                                  9.45
# fifty_two_week_low                             7.98
# fifty_two_week_high                           21.18
# sentiment_score                            0.335567
#            ex_eff_date  type  cash_amount     declaration_date record_date  \
# 0  2022-09-14 00:00:00  CASH        0.450  0001-01-01 00:00:00  2022-09-15
# 1  2022-06-22 00:00:00  CASH        0.450  2022-05-11 00:00:00  2022-06-23
# 2  2022-03-14 00:00:00  CASH        0.600  2022-03-04 00:00:00  2022-03-15
# 3  2021-12-14 00:00:00  CASH        0.100  2021-11-19 00:00:00  2021-12-15
# 4  2021-09-14 00:00:00  CASH        0.100  2021-08-23 00:00:00  2021-09-15
# 5  2021-06-14 00:00:00  CASH        0.100  2021-05-21 00:00:00  2021-06-15
# 6  2021-03-12 00:00:00  CASH        0.100  2021-02-24 00:00:00  2021-03-15
# 7  2020-12-30 00:00:00  CASH        0.083  2020-10-06 00:00:00  2020-12-31
# 8  2020-11-27 00:00:00  CASH        0.083  2020-10-06 00:00:00  2020-11-30
# 9  2020-10-29 00:00:00  CASH        0.083  2020-10-06 00:00:00  2020-10-30
#
#           payment_date
# 0  2022-09-30 00:00:00
# 1  2022-06-30 00:00:00
# 2  2022-03-30 00:00:00
# 3  2021-12-30 00:00:00
# 4  2021-09-30 00:00:00
# 5  2021-06-30 00:00:00
# 6  2021-03-31 00:00:00
# 7  2021-01-21 00:00:00
# 8  2020-12-21 00:00:00
# 9  2020-11-20 00:00:00
#                   label symbol ex_dividend_date  dividend_yield_pct  \
# 0  CIM Dividend History    CIM       2022-09-29               17.49
#
#    annual_dividend  pe_ratio  \
# 0             0.92       0.0
#
#                                                            nasdaq_url  \
# 0  https://www.nasdaq.com/market-activity/stocks/cim/dividend-history
#
#                              name exchange       sector      beta  \
# 0  Chimera Investment Corporation      NYQ  Real Estate  1.313559
#
#    current_price  fifty_two_week_low  fifty_two_week_high  \
# 0            5.9                4.91                16.85
#
#    five_year_avg_dividend_yield       earnings_date       dividend_date  \
# 0                         12.38 2022-11-03 20:30:00 2022-10-31 08:00:00
#
#    last_dividend_date  forward_eps  forward_pe  trailing_eps  trailing_pe  \
# 0 2022-09-29 08:00:00          1.1    5.363637          0.65     9.076923
#
#    peg_ratio  price_to_book free_cash_flow  return_on_equity  debt_to_equity  \
# 0      -1.77       0.459967           None           -0.0227         367.065
#
#    price_to_sales_trailing_12_months payout_ratio  dividend_yield  \
# 0                           18.20026         None          0.1559
#
#    dividend_rate  trailing_annual_dividend_rate  \
# 0           0.92                           1.32
#
#    trailing_annual_dividend_yield  \
# 0                        0.227194
#
#                                                yfinance_url  sentiment_score  \
# 0  https://finance.yahoo.com/quote/CIM/key-statistics?p=CIM         0.050075
#
#     source                             info_url
# 0  dataset  https://seekingalpha.com/symbol/CIM
# https://finance.yahoo.com/quote/CIM/key-statistics?p=CIM
#                                                   0
# sector                                  Real Estate
# trailing_annual_dividend_yield             0.227194
# dividend_yield_pct                            17.49
# earnings_date                   2022-11-03 20:30:00
# current_price                                   5.9
# fifty_two_week_low                             4.91
# fifty_two_week_high                           16.85
# sentiment_score                            0.050075
#   ex_eff_date  type  cash_amount declaration_date record_date payment_date
# 0  2022-09-29  CASH         0.23       2022-09-21  2022-09-30   2022-10-31
# 1  2022-06-29  CASH         0.33       2022-05-04  2022-06-30   2022-07-28
# 2  2022-03-30  CASH         0.33       2022-02-17  2022-03-31   2022-04-28
# 3  2021-12-29  CASH         0.33       2021-12-02  2021-12-30   2022-01-27
# 4  2021-09-29  CASH         0.33       2021-09-13  2021-09-30   2021-10-28
# 5  2021-06-29  CASH         0.33       2021-05-05  2021-06-30   2021-07-30
# 6  2021-03-30  CASH         0.30       2021-03-11  2021-03-31   2021-04-30
# 7  2020-12-29  CASH         0.30       2020-12-01  2020-12-30   2021-01-29
# 8  2020-09-28  CASH         0.30       2020-09-15  2020-09-29   2020-10-29
# 9  2020-06-19  CASH         0.30       2020-06-10  2020-06-22   2020-07-31
#                   label symbol ex_dividend_date  dividend_yield_pct  \
# 0  CIM Dividend History    CIM       2022-09-29               17.49
#
#    annual_dividend  pe_ratio  \
# 0             0.92       0.0
#
#                                                            nasdaq_url  \
# 0  https://www.nasdaq.com/market-activity/stocks/cim/dividend-history
#
#                              name exchange       sector      beta  \
# 0  Chimera Investment Corporation      NYQ  Real Estate  1.313559
#
#    current_price  fifty_two_week_low  fifty_two_week_high  \
# 0            5.9                4.91                16.85
#
#    five_year_avg_dividend_yield       earnings_date       dividend_date  \
# 0                         12.38 2022-11-03 20:30:00 2022-10-31 08:00:00
#
#    last_dividend_date  forward_eps  forward_pe  trailing_eps  trailing_pe  \
# 0 2022-09-29 08:00:00          1.1    5.363637          0.65     9.076923
#
#    peg_ratio  price_to_book free_cash_flow  return_on_equity  debt_to_equity  \
# 0      -1.77       0.459967           None           -0.0227         367.065
#
#    price_to_sales_trailing_12_months payout_ratio  dividend_yield  \
# 0                           18.20026         None          0.1559
#
#    dividend_rate  trailing_annual_dividend_rate  \
# 0           0.92                           1.32
#
#    trailing_annual_dividend_yield  \
# 0                        0.227194
#
#                                                yfinance_url  sentiment_score  \
# 0  https://finance.yahoo.com/quote/CIM/key-statistics?p=CIM         0.050075
#
#           source                             info_url
# 0  yahoo_finance  https://seekingalpha.com/symbol/CIM
# https://finance.yahoo.com/quote/CIM/key-statistics?p=CIM
#                                                   0
# sector                                  Real Estate
# trailing_annual_dividend_yield             0.227194
# dividend_yield_pct                            17.49
# earnings_date                   2022-11-03 20:30:00
# current_price                                   5.9
# fifty_two_week_low                             4.91
# fifty_two_week_high                           16.85
# sentiment_score                            0.050075
#   ex_eff_date  type  cash_amount declaration_date record_date payment_date
# 0  2022-09-29  CASH         0.23       2022-09-21  2022-09-30   2022-10-31
# 1  2022-06-29  CASH         0.33       2022-05-04  2022-06-30   2022-07-28
# 2  2022-03-30  CASH         0.33       2022-02-17  2022-03-31   2022-04-28
# 3  2021-12-29  CASH         0.33       2021-12-02  2021-12-30   2022-01-27
# 4  2021-09-29  CASH         0.33       2021-09-13  2021-09-30   2021-10-28
# 5  2021-06-29  CASH         0.33       2021-05-05  2021-06-30   2021-07-30
# 6  2021-03-30  CASH         0.30       2021-03-11  2021-03-31   2021-04-30
# 7  2020-12-29  CASH         0.30       2020-12-01  2020-12-30   2021-01-29
# 8  2020-09-28  CASH         0.30       2020-09-15  2020-09-29   2020-10-29
# 9  2020-06-19  CASH         0.30       2020-06-10  2020-06-22   2020-07-31
#                    label symbol ex_dividend_date  dividend_yield_pct  \
# 0  NEWT Dividend History   NEWT       2022-09-19               17.05
#
#    annual_dividend  pe_ratio  \
# 0              2.6      6.11
#
#                                                             nasdaq_url  \
# 0  https://www.nasdaq.com/market-activity/stocks/newt/dividend-history
#
#                              name exchange              sector      beta  \
# 0  Newtek Business Services Corp.      NGM  Financial Services  1.237288
#
#    current_price  fifty_two_week_low  fifty_two_week_high  \
# 0          15.53               14.75                32.38
#
#    five_year_avg_dividend_yield       earnings_date       dividend_date  \
# 0                         10.31 2022-11-08 05:00:00 2022-09-30 08:00:00
#
#    last_dividend_date  forward_eps  forward_pe  trailing_eps  trailing_pe  \
# 0 2022-09-19 08:00:00            3    5.176667          2.53      6.13834
#
#    peg_ratio  price_to_book  free_cash_flow  return_on_equity  debt_to_equity  \
# 0       1.93        0.95206       -25514124           0.15668         131.825
#
#    price_to_sales_trailing_12_months  payout_ratio  dividend_yield  \
# 0                           4.925866        1.3241          0.2033
#
#    dividend_rate  trailing_annual_dividend_rate  \
# 0            3.1                           3.35
#
#    trailing_annual_dividend_yield  \
# 0                        0.219672
#
#                                                  yfinance_url  \
# 0  https://finance.yahoo.com/quote/NEWT/key-statistics?p=NEWT
#
#    sentiment_score   source                              info_url
# 0        -0.013095  dataset  https://seekingalpha.com/symbol/NEWT
# https://finance.yahoo.com/quote/NEWT/key-statistics?p=NEWT
#                                                   0
# sector                           Financial Services
# trailing_annual_dividend_yield             0.219672
# dividend_yield_pct                            17.05
# earnings_date                   2022-11-08 05:00:00
# current_price                                 15.53
# fifty_two_week_low                            14.75
# fifty_two_week_high                           32.38
# sentiment_score                           -0.013095
#   ex_eff_date  type  cash_amount declaration_date record_date payment_date
# 0  2022-09-19  CASH         0.65       2022-08-30  2022-09-20   2022-09-30
# 1  2022-06-16  CASH         0.75       2022-04-20  2022-06-20   2022-06-30
# 2  2022-03-18  CASH         0.65       2021-12-20  2022-03-21   2022-03-31
# 3  2021-12-17  CASH         1.05       2021-10-20  2021-12-20   2021-12-30
# 4  2021-09-17  CASH         0.90       2021-08-09  2021-09-20   2021-09-30
# 5  2021-06-14  CASH         0.70       2021-05-11  2021-06-15   2021-06-30
# 6  2021-03-19  CASH         0.50       2021-02-23  2021-03-22   2021-03-31
# 7  2020-12-17  CASH         0.47       2020-11-10  2020-12-18   2020-12-30
# 8  2020-09-18  CASH         0.58       2020-07-20  2020-09-21   2020-09-30
# 9  2020-07-14  CASH         0.56       2020-06-12  2020-07-15   2020-07-31
#                   label symbol ex_dividend_date  dividend_yield_pct  \
# 0  TWO Dividend History    TWO       2022-09-30               20.48
#
#    annual_dividend  pe_ratio  \
# 0             0.68      5.38
#
#                                                            nasdaq_url  \
# 0  https://www.nasdaq.com/market-activity/stocks/two/dividend-history
#
#                           name exchange       sector      beta  current_price  \
# 0  Two Harbors Investment Corp      NYQ  Real Estate  1.663596           3.23
#
#    fifty_two_week_low  fifty_two_week_high  five_year_avg_dividend_yield  \
# 0                3.03                 6.55                          12.2
#
#         earnings_date       dividend_date  last_dividend_date  forward_eps  \
# 0 2022-11-09 05:00:00 2022-10-28 08:00:00 2022-09-30 08:00:00         0.72
#
#    forward_pe  trailing_eps  trailing_pe  peg_ratio  price_to_book  \
# 0    4.486111          0.62     5.209677       1.22       0.624637
#
#   free_cash_flow  return_on_equity  debt_to_equity  \
# 0           None           0.11188          385.48
#
#    price_to_sales_trailing_12_months  payout_ratio  dividend_yield  \
# 0                           6.163784        1.0968          0.2105
#
#    dividend_rate  trailing_annual_dividend_rate  \
# 0           0.68                           0.68
#
#    trailing_annual_dividend_yield  \
# 0                        0.210526
#
#                                                yfinance_url  sentiment_score  \
# 0  https://finance.yahoo.com/quote/TWO/key-statistics?p=TWO          0.08635
#
#     source                             info_url
# 0  dataset  https://seekingalpha.com/symbol/TWO
# https://finance.yahoo.com/quote/TWO/key-statistics?p=TWO
#                                                   0
# sector                                  Real Estate
# trailing_annual_dividend_yield             0.210526
# dividend_yield_pct                            20.48
# earnings_date                   2022-11-09 05:00:00
# current_price                                  3.23
# fifty_two_week_low                             3.03
# fifty_two_week_high                            6.55
# sentiment_score                             0.08635
#   ex_eff_date  type  cash_amount declaration_date record_date payment_date
# 0  2022-09-30  CASH         0.17       2022-09-21  2022-10-03   2022-10-28
# 1  2022-07-01  CASH         0.17       2022-06-22  2022-07-05   2022-07-29
# 2  2022-04-01  CASH         0.17       2022-03-23  2022-04-04   2022-04-29
# 3  2021-12-28  CASH         0.17       2021-12-16  2021-12-29   2022-01-28
# 4  2021-09-30  CASH         0.17       2021-09-21  2021-10-01   2021-10-29
# 5  2021-06-28  CASH         0.17       2021-06-17  2021-06-29   2021-07-29
# 6  2021-03-26  CASH         0.17       2021-03-18  2021-03-29   2021-04-29
# 7  2020-12-29  CASH         0.17       2020-12-17  2020-12-30   2021-01-29
# 8  2020-09-30  CASH         0.14       2020-09-21  2020-10-01   2020-10-29
# 9  2020-06-29  CASH         0.14       2020-06-18  2020-06-30   2020-07-29
#                   label symbol ex_dividend_date  dividend_yield_pct  \
# 0  WMC Dividend History    WMC       2022-09-30                14.3
#
#    annual_dividend  pe_ratio  \
# 0              1.6       0.0
#
#                                                            nasdaq_url  \
# 0  https://www.nasdaq.com/market-activity/stocks/wmc/dividend-history
#
#                              name exchange       sector      beta  \
# 0  Western Asset Mortgage Capital      NYQ  Real Estate  1.746499
#
#    current_price  fifty_two_week_low  fifty_two_week_high  \
# 0           9.88                8.86                 26.1
#
#    five_year_avg_dividend_yield       earnings_date       dividend_date  \
# 0                         15.47 2022-11-04 04:00:00 2022-10-26 08:00:00
#
#    last_dividend_date  forward_eps  forward_pe  trailing_eps trailing_pe  \
# 0 2022-09-30 08:00:00          2.9    3.406897        -1.369        None
#
#    peg_ratio  price_to_book free_cash_flow  return_on_equity  debt_to_equity  \
# 0       0.79       0.425275           None          -0.34968        1873.873
#
#    price_to_sales_trailing_12_months payout_ratio  dividend_yield  \
# 0                          -1.476257         None          0.1675
#
#    dividend_rate  trailing_annual_dividend_rate  \
# 0            1.6                              2
#
#    trailing_annual_dividend_yield  \
# 0                        0.209424
#
#                                                yfinance_url  sentiment_score  \
# 0  https://finance.yahoo.com/quote/WMC/key-statistics?p=WMC         0.496275
#
#     source                             info_url
# 0  dataset  https://seekingalpha.com/symbol/WMC
# https://finance.yahoo.com/quote/WMC/key-statistics?p=WMC
#                                                   0
# sector                                  Real Estate
# trailing_annual_dividend_yield             0.209424
# dividend_yield_pct                             14.3
# earnings_date                   2022-11-04 04:00:00
# current_price                                  9.88
# fifty_two_week_low                             8.86
# fifty_two_week_high                            26.1
# sentiment_score                            0.496275
#   ex_eff_date  type  cash_amount declaration_date record_date payment_date
# 0  2022-09-30  CASH         0.40       2022-09-22  2022-10-03   2022-10-26
# 1  2022-06-30  CASH         0.04       2022-06-21  2022-07-01   2022-07-25
# 2  2022-04-01  CASH         0.04       2022-03-23  2022-04-04   2022-04-26
# 3  2021-12-30  CASH         0.06       2021-12-21  2021-12-31   2022-01-26
# 4  2021-10-01  CASH         0.06       2021-09-23  2021-10-04   2021-10-26
# 5  2021-06-30  CASH         0.06       2021-06-22  2021-07-02   2021-07-26
# 6  2021-03-31  CASH         0.06       2021-03-23  2021-04-02   2021-04-26
# 7  2020-12-24  CASH         0.06       2020-12-17  2020-12-28   2021-01-26
# 8  2020-10-01  CASH         0.05       2020-09-22  2020-10-02   2020-10-26
# 9  2019-12-27  CASH         0.31       2019-12-19  2019-12-30   2020-01-24
#                    label symbol ex_dividend_date  dividend_yield_pct  \
# 0  CHMI Dividend History   CHMI       2022-09-29               21.14
#
#    annual_dividend  pe_ratio  \
# 0             1.08     14.66
#
# ...
# 0            1.2                            1.2
#
#    trailing_annual_dividend_yield  \
# 0                        0.056872
#
#                                                  yfinance_url  \
# 0  https://finance.yahoo.com/quote/PBFX/key-statistics?p=PBFX
#
#    sentiment_score   source                              info_url
# 0         0.298233  dataset  https://seekingalpha.com/symbol/PBFX
# https://finance.yahoo.com/quote/PBFX/key-statistics?p=PBFX
#                                                   0
# sector                                       Energy
# trailing_annual_dividend_yield             0.056872
# dividend_yield_pct                             5.69
# earnings_date                   2022-10-27 20:30:00
# current_price                                 21.15
# fifty_two_week_low                            10.65
# fifty_two_week_high                           21.84
# sentiment_score                            0.298233
#   ex_eff_date  type  cash_amount declaration_date record_date payment_date
# 0  2022-08-10  CASH          0.3       2022-07-28  2022-08-11   2022-08-25
# 1  2022-05-11  CASH          0.3       2022-04-28  2022-05-12   2022-05-26
# 2  2022-02-23  CASH          0.3       2022-02-10  2022-02-24   2022-03-10
# 3  2021-11-10  CASH          0.3       2021-10-28  2021-11-12   2021-11-30
# 4  2021-08-11  CASH          0.3       2021-07-29  2021-08-12   2021-08-26
# 5  2021-05-12  CASH          0.3       2021-04-29  2021-05-13   2021-05-27
# 6  2021-02-24  CASH          0.3       2021-02-11  2021-02-25   2021-03-17
# 7  2020-11-13  CASH          0.3       2020-10-29  2020-11-16   2020-11-30
# 8  2020-08-12  CASH          0.3       2020-07-31  2020-08-13   2020-08-26
# 9  2020-05-26  CASH          0.3       2020-05-15  2020-05-27   2020-06-17
#                   label symbol ex_dividend_date  dividend_yield_pct  \
# 0  DCP Dividend History    DCP       2022-07-28                4.37
#
#    annual_dividend  pe_ratio  \
# 0             1.72     10.43
#
#                                                            nasdaq_url  \
# 0  https://www.nasdaq.com/market-activity/stocks/dcp/dividend-history
#
#                  name exchange  sector      beta  current_price  \
# 0  DCP Midstream,  LP      NYQ  Energy  2.542372          38.69
#
#    fifty_two_week_low  fifty_two_week_high  five_year_avg_dividend_yield  \
# 0               23.58                39.65                         11.17
#
#         earnings_date       dividend_date  last_dividend_date  forward_eps  \
# 0 2022-10-31 18:59:00 2022-11-14 08:00:00 2022-07-28 08:00:00         4.96
#
#    forward_pe  trailing_eps  trailing_pe  peg_ratio  price_to_book  \
# 0    7.800403           3.7    10.456757       0.32       1.500252
#
#    free_cash_flow  return_on_equity  debt_to_equity  \
# 0       277875008           0.14113          84.829
#
#    price_to_sales_trailing_12_months  payout_ratio  dividend_yield  \
# 0                           0.564081        0.4216          0.0437
#
#    dividend_rate  trailing_annual_dividend_rate  \
# 0           1.72                            1.6
#
#    trailing_annual_dividend_yield  \
# 0                        0.040619
#
#                                                yfinance_url  sentiment_score  \
# 0  https://finance.yahoo.com/quote/DCP/key-statistics?p=DCP         0.174858
#
#     source                             info_url
# 0  dataset  https://seekingalpha.com/symbol/DCP
# https://finance.yahoo.com/quote/DCP/key-statistics?p=DCP
#                                                   0
# sector                                       Energy
# trailing_annual_dividend_yield             0.040619
# dividend_yield_pct                             4.37
# earnings_date                   2022-10-31 18:59:00
# current_price                                 38.69
# fifty_two_week_low                            23.58
# fifty_two_week_high                           39.65
# sentiment_score                            0.174858
#   ex_eff_date  type  cash_amount declaration_date record_date payment_date
# 0  2022-07-28  CASH         0.43       2022-07-19  2022-07-29   2022-08-12
# 1  2022-04-28  CASH         0.39       2022-04-19  2022-04-29   2022-05-13
# 2  2022-02-03  CASH         0.39       2022-01-24  2022-02-04   2022-02-14
# 3  2021-10-28  CASH         0.39       2021-10-12  2021-10-29   2021-11-12
# 4  2021-07-29  CASH         0.39       2021-07-20  2021-07-30   2021-08-13
# 5  2021-02-04  CASH         0.39       2021-01-21  2021-02-05   2021-02-12
# 6  2020-10-29  CASH         0.39       2020-10-16  2020-10-30   2020-11-13
# 7  2020-07-30  CASH         0.39       2020-07-21  2020-07-31   2020-08-14
# 8  2020-04-30  CASH         0.39       2020-04-21  2020-05-01   2020-05-15
# 9  2020-01-31  CASH         0.78       2020-01-22  2020-02-03   2020-02-14
#   label symbol     ex_dividend_date  dividend_yield_pct  annual_dividend  \
# 0         ENLC  0001-01-01 00:00:00                   0                0
#
#    pe_ratio  \
# 0         0
#
#                                                             nasdaq_url  \
# 0  https://www.nasdaq.com/market-activity/stocks/enlc/dividend-history
#
#                     name exchange  sector      beta  current_price  \
# 0  EnLink Midstream, LLC      NYQ  Energy  2.520265          11.01
#
#    fifty_two_week_low  fifty_two_week_high  five_year_avg_dividend_yield  \
# 0                5.88                11.85                          12.6
#
#         earnings_date       dividend_date  last_dividend_date  forward_eps  \
# 0 2022-11-02 04:00:00 2022-08-12 08:00:00 2022-07-28 08:00:00         0.59
#
#    forward_pe  trailing_eps  trailing_pe  peg_ratio  price_to_book  \
# 0   18.661018          0.37    29.756758       0.28       4.088377
#
#    free_cash_flow  return_on_equity  debt_to_equity  \
# 0       491262496           0.10353         149.387
#
#    price_to_sales_trailing_12_months  payout_ratio  dividend_yield  \
# 0                           0.590931        1.1149          0.0407
#
#    dividend_rate  trailing_annual_dividend_rate  \
# 0           0.45                          0.431
#
#    trailing_annual_dividend_yield  \
# 0                        0.038969
#
#                                                  yfinance_url  \
# 0  https://finance.yahoo.com/quote/ENLC/key-statistics?p=ENLC
#
#    sentiment_score   source                              info_url
# 0         0.131177  dataset  https://seekingalpha.com/symbol/ENLC
# https://finance.yahoo.com/quote/ENLC/key-statistics?p=ENLC
#                                                   0
# sector                                       Energy
# trailing_annual_dividend_yield             0.038969
# dividend_yield_pct                                0
# earnings_date                   2022-11-02 04:00:00
# current_price                                 11.01
# fifty_two_week_low                             5.88
# fifty_two_week_high                           11.85
# sentiment_score                            0.131177
# Empty DataFrame
# Columns: []
# Index: []
#                    label symbol ex_dividend_date  dividend_yield_pct  \
# 0  MMLP Dividend History   MMLP       2022-08-04                0.59
#
#    annual_dividend  pe_ratio  \
# 0             0.02      6.08
#
#                                                             nasdaq_url  \
# 0  https://www.nasdaq.com/market-activity/stocks/mmlp/dividend-history
#
#                              name exchange  sector      beta  current_price  \
# 0  Martin Midstream Partners L.P.      NMS  Energy  2.134856          3.405
#
#    fifty_two_week_low  fifty_two_week_high  five_year_avg_dividend_yield  \
# 0                2.52                 5.98                         16.08
#
#         earnings_date       dividend_date  last_dividend_date  forward_eps  \
# 0 2022-11-03 04:00:00 2022-11-14 08:00:00 2022-08-04 08:00:00         0.05
#
#    forward_pe  trailing_eps  trailing_pe peg_ratio price_to_book  \
# 0        68.1          0.55     6.190909      None          None
#
#    free_cash_flow return_on_equity debt_to_equity  \
# 0        32374500             None           None
#
#    price_to_sales_trailing_12_months  payout_ratio  dividend_yield  \
# 0                           0.126789        0.0364          0.0059
#
#    dividend_rate  trailing_annual_dividend_rate  \
# 0           0.02                           0.02
#
#    trailing_annual_dividend_yield  \
# 0                        0.005917
#
#                                                  yfinance_url  \
# 0  https://finance.yahoo.com/quote/MMLP/key-statistics?p=MMLP
#
#    sentiment_score   source                              info_url
# 0         0.112189  dataset  https://seekingalpha.com/symbol/MMLP
# https://finance.yahoo.com/quote/MMLP/key-statistics?p=MMLP
#                                                   0
# sector                                       Energy
# trailing_annual_dividend_yield             0.005917
# dividend_yield_pct                             0.59
# earnings_date                   2022-11-03 04:00:00
# current_price                                 3.405
# fifty_two_week_low                             2.52
# fifty_two_week_high                            5.98
# sentiment_score                            0.112189
#   ex_eff_date  type  cash_amount     declaration_date record_date  \
# 0  2022-11-04  CASH        0.005  2022-10-18 00:00:00  2022-11-07
# 1  2022-08-04  CASH        0.005  2022-07-20 00:00:00  2022-08-05
# 2  2022-05-05  CASH        0.005  2022-04-20 00:00:00  2022-05-06
# 3  2022-02-04  CASH        0.005  2022-01-25 00:00:00  2022-02-07
# 4  2021-11-04  CASH        0.005  2021-10-20 00:00:00  2021-11-05
# 5  2021-08-05  CASH        0.005  2021-07-22 00:00:00  2021-08-06
# 6  2021-05-06  CASH        0.005  2021-04-21 00:00:00  2021-05-07
# 7  2021-02-04  CASH        0.005  2021-01-25 00:00:00  2021-02-05
# 8  2020-11-05  CASH        0.005  2020-10-21 00:00:00  2020-11-06
# 9  2020-08-06  CASH        0.005  2020-07-27 00:00:00  2020-08-07
#
#           payment_date
# 0  2022-11-14 00:00:00
# 1  2022-08-12 00:00:00
# 2  2022-05-13 00:00:00
# 3  2022-02-14 00:00:00
# 4  2021-11-12 00:00:00
# 5  2021-08-13 00:00:00
# 6  2021-05-14 00:00:00
# 7  2021-02-12 00:00:00
# 8  2020-11-13 00:00:00
# 9  2020-08-14 00:00:00
#                  label symbol ex_dividend_date  dividend_yield_pct  \
# 0  DX Dividend History     DX       2022-10-20               13.38
#
#    annual_dividend  pe_ratio  \
# 0             1.56      2.45
#
#                                                           nasdaq_url  \
# 0  https://www.nasdaq.com/market-activity/stocks/dx/dividend-history
#
#                   name exchange       sector  beta  current_price  \
# 0  Dynex Capital, Inc.      NYQ  Real Estate  None          10.97
#
#    fifty_two_week_low  fifty_two_week_high  five_year_avg_dividend_yield  \
# 0               10.92                18.05                          11.4
#
#         earnings_date       dividend_date  last_dividend_date  forward_eps  \
# 0 2022-10-24 22:00:00 2022-11-01 08:00:00 2022-10-20 08:00:00         1.26
#
#    forward_pe  trailing_eps  trailing_pe  peg_ratio  price_to_book  \
# 0    8.706349          3.98     2.756281      -1.37       0.606278
#
#   free_cash_flow return_on_equity debt_to_equity  \
# 0           None             None           None
#
#   price_to_sales_trailing_12_months  payout_ratio  dividend_yield  \
# 0                              None        0.3679          0.1336
#
#    dividend_rate  trailing_annual_dividend_rate  \
# 0           1.56                              0
#
#    trailing_annual_dividend_yield  \
# 0                               0
#
#                                              yfinance_url  sentiment_score  \
# 0  https://finance.yahoo.com/quote/DX/key-statistics?p=DX        -0.146921
#
#     source                            info_url
# 0  dataset  https://seekingalpha.com/symbol/DX
# https://finance.yahoo.com/quote/DX/key-statistics?p=DX
#                                                   0
# sector                                  Real Estate
# trailing_annual_dividend_yield                    0
# dividend_yield_pct                            13.38
# earnings_date                   2022-10-24 22:00:00
# current_price                                 10.97
# fifty_two_week_low                            10.92
# fifty_two_week_high                           18.05
# sentiment_score                           -0.146921
#   ex_eff_date  type  cash_amount declaration_date record_date payment_date
# 0  2022-10-20  CASH         0.13       2022-10-10  2022-10-21   2022-11-01
# 1  2022-09-22  CASH         0.13       2022-09-13  2022-09-23   2022-10-03
# 2  2022-08-19  CASH         0.13       2022-08-11  2022-08-22   2022-09-01
# 3  2022-07-21  CASH         0.13       2022-07-12  2022-07-22   2022-08-01
# 4  2022-06-23  CASH         0.13       2022-06-14  2022-06-24   2022-07-01
# 5  2022-05-20  CASH         0.13       2022-05-13  2022-05-23   2022-06-01
# 6  2022-04-21  CASH         0.13       2022-04-12  2022-04-22   2022-05-02
# 7  2022-03-21  CASH         0.13       2022-03-11  2022-03-22   2022-04-01
# 8  2022-02-18  CASH         0.13       2022-02-10  2022-02-22   2022-03-01
# 9  2022-01-21  CASH         0.13       2022-01-13  2022-01-24   2022-02-01
#                    label symbol ex_dividend_date  dividend_yield_pct  \
# 0  HIMX Dividend History   HIMX       2022-06-29               21.15
#
#    annual_dividend  pe_ratio  \
# 0             1.25      2.29
#
#                                                             nasdaq_url  \
# 0  https://www.nasdaq.com/market-activity/stocks/himx/dividend-history
#
#                        name exchange      sector      beta  current_price  \
# 0  Himax Technologies, Inc.      NMS  Technology  1.972365           5.85
#
#    fifty_two_week_low  fifty_two_week_high five_year_avg_dividend_yield  \
# 0                4.81                 16.5                         None
#
#         earnings_date       dividend_date  last_dividend_date  forward_eps  \
# 0 2022-11-10 21:00:00 2022-07-12 08:00:00 2022-06-29 08:00:00         0.52
#
#    forward_pe  trailing_eps  trailing_pe peg_ratio  price_to_book  \
# 0       11.25          2.68     2.182836      None       1.216722
#
#    free_cash_flow  return_on_equity  debt_to_equity  \
# 0       324474112           0.61147          23.884
#
#    price_to_sales_trailing_12_months  payout_ratio  dividend_yield  \
# 0                           0.637978        0.4881          0.2115
#
#    dividend_rate  trailing_annual_dividend_rate  \
# 0           1.25                              0
#
#    trailing_annual_dividend_yield  \
# 0                               0
#
#                                                  yfinance_url  \
# 0  https://finance.yahoo.com/quote/HIMX/key-statistics?p=HIMX
#
#    sentiment_score         source                              info_url
# 0         0.021509  yahoo_finance  https://seekingalpha.com/symbol/HIMX
# https://finance.yahoo.com/quote/HIMX/key-statistics?p=HIMX
#                                                   0
# sector                                   Technology
# trailing_annual_dividend_yield                    0
# dividend_yield_pct                            21.15
# earnings_date                   2022-11-10 21:00:00
# current_price                                  5.85
# fifty_two_week_low                             4.81
# fifty_two_week_high                            16.5
# sentiment_score                            0.021509
#   ex_eff_date  type  cash_amount     declaration_date record_date payment_date
# 0  2022-06-29  CASH        1.250  2022-05-23 00:00:00  2022-06-30   2022-07-12
# 1  2021-06-29  CASH        0.272  2021-05-28 00:00:00  2021-06-30   2021-07-12
# 2  2018-07-18  CASH        0.100  2018-06-19 00:00:00  2018-07-19   2018-07-31
# 3  2017-07-27  CASH        0.240  0001-01-01 00:00:00  2017-07-31   2017-08-14
# 4  2016-07-20  CASH        0.130  2016-06-20 00:00:00  2016-07-22   2016-08-03
# 5  2015-06-24  CASH        0.300  2015-05-11 00:00:00  2015-06-26   2015-07-08
# 6  2014-07-09  CASH        0.270  2014-06-24 00:00:00  2014-07-11   2014-07-23
# 7  2013-07-17  CASH        0.250  2013-06-17 00:00:00  2013-07-19   2013-07-31

# %% [markdown]
# Stocks to track
# - PBR-A
# - PBR
# - GOGL
# - ORC - monthly
# - OXLC - monthly
