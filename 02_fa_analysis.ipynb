# %%
from IPython.core.interactiveshell import InteractiveShell
from IPython.display import display
InteractiveShell.ast_node_interactivity = "all"

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
# %matplotlib inline
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
COUNTRY = "united states"
FILE = "alphalib_united_states.xlsx"
SHEET_NAME_STOCK_INFO = "stock_info"
SHEET_NAME_STOCK_FINANCIALS = "stock_financials"
SHEET_NAME_STOCK_DIVIDENDS = "stock_dividends"

# %%
stock_info = pd.read_excel(FILE, sheet_name=SHEET_NAME_STOCK_INFO, engine="openpyxl")
stock_financials = pd.read_excel(FILE, sheet_name=SHEET_NAME_STOCK_FINANCIALS, engine="openpyxl")
stock_dividends = pd.read_excel(FILE, sheet_name=SHEET_NAME_STOCK_DIVIDENDS, engine="openpyxl")

# %%
stock_info.head()
# Out:
#    52WeekChange  SandP52WeekChange                          address1  \
# 0     -0.274329          -0.128269         100 North Riverside Plaza
# 1     -0.219408          -0.128269            300 Renaissance Center
# 2      0.617644          -0.128269        6001 Bollinger Canyon Road
# 3     -0.317343          -0.128269              388 Greenwich Street
# 4     -0.180644          -0.128269  Bank of America Corporate Center
#
#    algorithm  annualHoldingsTurnover  annualReportExpenseRatio  ask  askSize  \
# 0        NaN                     NaN                       NaN    0     1000
# 1        NaN                     NaN                       NaN    0     1100
# 2        NaN                     NaN                       NaN    0      900
# 3        NaN                     NaN                       NaN    0     1300
# 4        NaN                     NaN                       NaN    0     3000
#
#    averageDailyVolume10Day  averageVolume  averageVolume10days      beta  \
# ...

# %%
stock_financials.head()
# Out:
#    Cost Of Revenue        Country       Date  Discontinued Operations  \
# 0      57096000000  united states 2021-12-31                      NaN
# 1      59356000000  united states 2020-12-31                      NaN
# 2      71800000000  united states 2019-12-31                      NaN
# 3      81490000000  united states 2018-12-31                      NaN
# 4     108925000000  united states 2021-12-31                      NaN
#
#           Ebit  Effect Of Accounting Charges  Extraordinary Items  \
# 0   -687000000                           NaN                  NaN
# 1  -8167000000                           NaN                  NaN
# 2  -2102000000                           NaN                  NaN
# 3  11843000000                           NaN                  NaN
# 4  11434000000                           NaN                  NaN
#
#                 Full Name  Gross Profit  Income Before Tax  \
# 0               Boeing Co    5190000000        -5033000000
# ...

# %%
stock_dividends.head()
# Out:
#          Country       Date  Dividend  Full Name    Name Payment Date Symbol  \
# 0  united states 2020-02-13     2.055  Boeing Co  Boeing   2020-03-06     BA
# 1  united states 2019-11-07     2.055  Boeing Co  Boeing   2019-12-06     BA
# 2  united states 2019-08-08     2.055  Boeing Co  Boeing   2019-09-06     BA
# 3  united states 2019-05-09     2.055  Boeing Co  Boeing   2019-06-07     BA
# 4  united states 2019-02-07     2.055  Boeing Co  Boeing   2019-03-01     BA
#
#         Type  Yield
# 0  quarterly  2.37%
# 1  quarterly  2.32%
# 2  quarterly  2.48%
# 3  quarterly  2.28%
# 4  quarterly  2.00%

# %%
dtypes
